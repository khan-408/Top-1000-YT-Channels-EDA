# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r'H:\csvs\Most subscribed Youtube channels\topSubscribed.csv')

# %%
df.head()
# Out:
#    Rank             Youtube Channel  Subscribers      Video Views Video Count  \
# 0     1                    T-Series  234,000,000  212,900,271,553      18,515
# 1     2              YouTube Movies  161,000,000                0           0
# 2     3  Cocomelon - Nursery Rhymes  152,000,000  149,084,178,448         846
# 3     4                   SET India  150,000,000  137,828,094,104     103,200
# 4     5                     MrBeast  128,000,000   21,549,128,785         733
#
#            Category  Started
# 0             Music     2006
# 1  Film & Animation     2015
# 2         Education     2006
# 3             Shows     2006
# 4     Entertainment     2012

# %%
df.isnull().sum()
# Out:
# Rank               0
# Youtube Channel    0
# Subscribers        0
# Video Views        0
# Video Count        0
# Category           0
# Started            0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Rank             1000 non-null   int64
#  1   Youtube Channel  1000 non-null   object
#  2   Subscribers      1000 non-null   object
#  3   Video Views      1000 non-null   object
#  4   Video Count      1000 non-null   object
#  5   Category         1000 non-null   object
#  6   Started          1000 non-null   int64
# dtypes: int64(2), object(5)
# memory usage: 54.8+ KB

# %%
col=['Subscribers','Video Views','Video Count']
for i in col:
    df[i]=df[i].str.replace(',','')

# %%
col=['Subscribers','Video Views','Video Count']

for i in col:
    df[i] = df[i].astype("int64")

# %%
df
# Out:
#      Rank             Youtube Channel  Subscribers   Video Views  Video Count  \
# 0       1                    T-Series    234000000  212900271553        18515
# 1       2              YouTube Movies    161000000             0            0
# 2       3  Cocomelon - Nursery Rhymes    152000000  149084178448          846
# 3       4                   SET India    150000000  137828094104       103200
# 4       5                     MrBeast    128000000   21549128785          733
# ..    ...                         ...          ...           ...          ...
# 995   996                     XO TEAM     11500000   11471384709         2679
# 996   997         Nirahua Music World     11500000    5997717755          788
# 997   998                     YtCrash     11400000       3825084            1
# 998   999                   Painzeiro     11400000    2143444281          946
# 999  1000                   Oum Walid     11400000    2480064722         1598
#
#              Category  Started
# ...

# %%
new_df =df[['Youtube Channel','Started']]

# %%
new_df
# Out:
#                 Youtube Channel  Started
# 0                      T-Series     2006
# 1                YouTube Movies     2015
# 2    Cocomelon - Nursery Rhymes     2006
# 3                     SET India     2006
# 4                       MrBeast     2012
# ..                          ...      ...
# 995                     XO TEAM     2021
# 996         Nirahua Music World     2014
# 997                     YtCrash     2015
# 998                   Painzeiro     2015
# 999                   Oum Walid     2015
#
# [1000 rows x 2 columns]

# %%
new_df=new_df.groupby('Started').count()

# %%
new_df
# Out:
#          Youtube Channel
# Started
# 1970                   1
# 2005                  21
# 2006                  69
# 2007                  45
# 2008                  45
# 2009                  59
# 2010                  45
# 2011                  87
# 2012                  81
# 2013                  88
# 2014                 120
# 2015                  95
# 2016                  76
# 2017                  62
# 2018                  50
# 2019                  30
# 2020                  15
# 2021                  11

# %%
plt.figure(figsize=(16,8))
sns.set_theme(style='whitegrid')
ax=sns.barplot(x=new_df.index,y='Youtube Channel',data=new_df)

# %%
df.Category.value_counts()
# Out:
# Entertainment                                                                   238
# Music                                                                           217
# People & Blogs                                                                  132
# Gaming                                                                           94
# Comedy                                                                           68
# Film & Animation                                                                 50
# Education                                                                        45
# Howto & Style                                                                    43
# https://us.youtubers.me/global/all/top-1000-most_subscribed-youtube-channels     30
# News & Politics                                                                  27
# Science & Technology                                                             18
# ...

# %%
df[df['Category']=='https://us.youtubers.me/global/all/top-1000-most_subscribed-youtube-channels']
# Out:
#      Rank                                    Youtube Channel  Subscribers  \
# 5       6                                              Music    118000000
# 9      10                                             Gaming     93300000
# 17     18                                             Sports     75100000
# 91     92                                               News     36300000
# 106   107                                       Vlad và Niki     33900000
# 154   155                                 Popular on YouTube     29300000
# 166   167                                    व्लाद और निकिता     28700000
# 219   220           Super JoJo - Nursery Rhymes & Kids Songs     24400000
# 220   221                                         D Billions     24400000
# 254   255                                 Diana and Roma ARA     23000000
# 294   295                               Vlad and Niki Arabic     21100000
# 317   318                                        BETER BÖCÜK     20300000
# ...

# %%
df['Category']=df['Category'].str.replace('https://us.youtubers.me/global/all/top-1000-most_subscribed-youtube-channels', 'Other')
# Out:
# C:\Users\WELCOME\AppData\Local\Temp\ipykernel_3568\1631456580.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Category']=df['Category'].str.replace('https://us.youtubers.me/global/all/top-1000-most_subscribed-youtube-channels', 'Other')

# %%
df.Category.value_counts()
# Out:
# Entertainment            238
# Music                    217
# People & Blogs           132
# Gaming                    94
# Comedy                    68
# Film & Animation          50
# Education                 45
# Howto & Style             43
# Other                     30
# News & Politics           27
# Science & Technology      18
# Shows                     14
# Sports                    10
# Pets & Animals             6
# Trailers                   2
# Nonprofits & Activism      2
# Movies                     2
# Autos & Vehicles           1
# Travel & Events            1
# Name: Category, dtype: int64

# %%
df_pie= df.groupby('Category').count()

# %%
df_pie
# Out:
#                        Rank  Youtube Channel  Subscribers  Video Views  \
# Category
# Autos & Vehicles          1                1            1            1
# Comedy                   68               68           68           68
# Education                45               45           45           45
# Entertainment           238              238          238          238
# Film & Animation         50               50           50           50
# Gaming                   94               94           94           94
# Howto & Style            43               43           43           43
# Movies                    2                2            2            2
# Music                   217              217          217          217
# News & Politics          27               27           27           27
# Nonprofits & Activism     2                2            2            2
# Other                    30               30           30           30
# ...

# %%
prcnt =( df_pie['Youtube Channel']/df_pie['Youtube Channel'].sum())*100
sns.set()
plt.figure(figsize=(12,8))
plt.pie(df_pie['Youtube Channel'],autopct='%1.1f%%')
labels=df_pie.index
plt.legend(labels,loc='upper right', bbox_to_anchor=(-0.1, 1.))
plt.title("Category wise channel counts")
# Out:
# Text(0.5, 1.0, 'Category wise channel counts')

# %% [markdown]
# ### Understanding the correlation b/w features

# %%
sns.pairplot(df)

# %% [markdown]
# Observation:- As we can see clearly, The 'subsribers' and 'video views' are correlated positively.

# %%
plt.figure(figsize=(10,6))
corr=df.corr()
mask=np.triu(np.ones_like(corr, dtype=bool))
cmap = sns.diverging_palette(230, 20, as_cmap=True)

sns.heatmap(corr,annot=True, mask=mask, cmap=cmap)
# Out:
# C:\Users\WELCOME\AppData\Local\Temp\ipykernel_3568\2702871427.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr=df.corr()
# <AxesSubplot:>

# %%
#views Vs subscribers 
plt.figure(figsize=(12,6))
sns.scatterplot(x= df['Video Views'] , y = df['Subscribers'] , data = df)
#Showing linear Relationship
# Out:
# <AxesSubplot:xlabel='Video Views', ylabel='Subscribers'>
